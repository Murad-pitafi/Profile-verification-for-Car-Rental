# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import joblib

# %%
df=pd.read_csv('D:\Profile-verification-for-Car-Rental\linkedin_profiles_with_categories.csv')

# %%
df.head(10)
# Out:
#   Education  Experience (Years)  Experience (Months)  Connections  \
# 0        MS                   5                    9           13
# 1        BS                   6                    1          109
# 2        MS                   0                    5          358
# 3       PhD                   5                    1            8
# 4       PhD                   7                    9          326
# 5        BS                   6                    3          379
# 6        MS                   7                    2           36
# 7        BS                   5                    9          364
# 8        BS                   6                    4          385
# 9       PhD                   7                    7          316
#
#    Recent Post (Months Ago)  Reactions on Recent Post  \
# 0                         8                       492
# 1                         3                       515
# 2                         4                       932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Education                    500 non-null    object
#  1   Experience (Years)           500 non-null    int64
#  2   Experience (Months)          500 non-null    int64
#  3   Connections                  500 non-null    int64
#  4   Recent Post (Months Ago)     500 non-null    int64
#  5   Reactions on Recent Post     500 non-null    int64
#  6   Comments on Recent Post      500 non-null    int64
#  7   Repost Count on Recent Post  500 non-null    int64
#  8   Category                     500 non-null    object
#  9   Score                        500 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 39.2+ KB

# %%
# df['Headline'] = LabelEncoder().fit_transform(df['Headline'])
df['Category'] = LabelEncoder().fit_transform(df['Category'])
df['Education'] = LabelEncoder().fit_transform(df['Education'])

# %%
df.head(10)
# Out:
#    Education  Experience (Years)  Experience (Months)  Connections  \
# 0          1                   5                    9           13
# 1          0                   6                    1          109
# 2          1                   0                    5          358
# 3          2                   5                    1            8
# 4          2                   7                    9          326
# 5          0                   6                    3          379
# 6          1                   7                    2           36
# 7          0                   5                    9          364
# 8          0                   6                    4          385
# 9          2                   7                    7          316
#
#    Recent Post (Months Ago)  Reactions on Recent Post  \
# 0                         8                       492
# 1                         3                       515
# 2                         4                       932
# ...

# %%
X = df.drop(columns=['Category', 'Score'])  # Drop 'username' as it’s likely not useful for prediction
y = df['Category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Standardizing numerical features
    ('clf', LogisticRegression())  # Classifier
])

# %%
pipeline.fit(X_train, y_train)

# Testing the model
y_pred = pipeline.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.62      0.77         8
#            1       0.80      0.83      0.82        72
#            2       0.73      0.73      0.73        45
#
#     accuracy                           0.78       125
#    macro avg       0.84      0.73      0.77       125
# weighted avg       0.79      0.78      0.78       125

# %%
print(pipeline.score(X_train, y_train))
print(pipeline.score(X_test, y_test))
# Out:
# 0.864
# 0.784

# %%
joblib.dump(pipeline, 'profile_verification_synthetic_model.pkl')
print("Model saved as 'profile_verification_synthetic_model.pkl'")
# Out:
# Model saved as 'profile_verification_synthetic_model.pkl'
