# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import joblib

# %%
df = pd.read_csv('D:\Profile-verification-for-Car-Rental\profileclassData - Sheet1.csv')

# # Preprocessing
# df['Company Verified'] = df['Company Verified'].map({'YES': 1, 'NO': 0})
# df['Target'] = df['Target'].map({'Verified': 1, 'Not Verified': 0})
# df['Followers'] = df['Followers'].apply(lambda x: int(str(x).replace(',', '')))  # Convert 'Followers' to int

# %%
df.head()
# Out:
#                  Name  Experience  Education Level  Followers  \
# 0      Ehtesham Zafar           5                8         10
# 1       Ayesha Irshad           5                3         10
# 2  Suhail Ahmed Malik          10                7         10
# 3       VARUN BISARIA          10                6          5
# 4     Viktoria Semaan          18                8         10
#
#    Skill Endorsements  Recommendations  Activity  projects  Certificates  \
# 0                   3                0         3         4            10
# 1                  15               10         6         8            10
# 2                  15                0         6        15            10
# 3                   8                0         7         0             5
# 4                  15                5        10         0            10
#
#   Class Type
# 0          C
# 1          B
# 2          B
# 3          C
# 4          B

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                14 non-null     object
#  1   Experience          14 non-null     int64
#  2   Education Level     14 non-null     int64
#  3   Followers           14 non-null     int64
#  4   Skill Endorsements  14 non-null     int64
#  5   Recommendations     14 non-null     int64
#  6   Activity            14 non-null     int64
#  7   projects            14 non-null     int64
#  8   Certificates        14 non-null     int64
#  9   Class Type          14 non-null     object
# dtypes: int64(8), object(2)
# memory usage: 1.2+ KB

# %%
# df['Headline'] = LabelEncoder().fit_transform(df['Headline'])
df['Class Type'] = LabelEncoder().fit_transform(df['Class Type'])

# %%
df.head(10)
# Out:
#                  Name  Experience  Education Level  Followers  \
# 0      Ehtesham Zafar           5                8         10
# 1       Ayesha Irshad           5                3         10
# 2  Suhail Ahmed Malik          10                7         10
# 3       VARUN BISARIA          10                6          5
# 4     Viktoria Semaan          18                8         10
# 5       Mujtaba Saqib           3                5         10
# 6          Ziyaan Ali          10                3         10
# 7        Danish Ahmed          10                2          3
# 8     Ibtehaj Tarique           2                8          5
# 9      Muhammad Usama           5                3         10
#
#    Skill Endorsements  Recommendations  Activity  projects  Certificates  \
# 0                   3                0         3         4            10
# 1                  15               10         6         8            10
# 2                  15                0         6        15            10
# 3                   8                0         7         0             5
# 4                  15                5        10         0            10
# 5                   2                0         7        15             5
# 6                   8                0         3         0            10
# 7                   8                0         1         0             0
# 8                   8                0         4         0             0
# 9                  15                2         5         2            10
#
#    Class Type
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# 5           1
# 6           1
# 7           2
# 8           2
# 9           0

# %%
X = df.drop(columns=['Name', 'Class Type'])  # Drop 'username' as it’s likely not useful for prediction
y = df['Class Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Standardizing numerical features
    ('clf', LogisticRegression())  # Classifier
])

# %%
pipeline.fit(X_train, y_train)

# Testing the model
y_pred = pipeline.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.75         4
#    macro avg       0.83      0.75      0.73         4
# weighted avg       0.83      0.75      0.73         4

# %%
print(pipeline.score(X_train, y_train))
print(pipeline.score(X_test, y_test))
# Out:
# 1.0
# 0.75

# %%
joblib.dump(pipeline, 'profile_verification_model.pkl')
print("Model saved as 'profile_verification_model.pkl'")
# Out:
# Model saved as 'profile_verification_model.pkl'
